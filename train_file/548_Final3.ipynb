# %%
# importing the general dependencies

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os
import io
import zipfile
import warnings
from google.colab import files
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile
import os

zip_file_path = '/content/drive/My Drive/YOLO_archive.zip'
destination_folder = '/content/YOLO_data'
os.makedirs(destination_folder, exist_ok=True)
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(destination_folder)

# %%
# !unzip /content/drive/MyDrive/venv.zip -d /content/
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#   inflating: /content/venv/Lib/site-packages/torch/include/ATen/ops/upsample_nearest3d_cuda_dispatch.h
#   inflating: /content/venv/Lib/site-packages/torch/include/ATen/ops/upsample_nearest3d_meta.h
#   inflating: /content/venv/Lib/site-packages/torch/include/ATen/ops/upsample_nearest3d_meta_dispatch.h
#   inflating: /content/venv/Lib/site-packages/torch/include/ATen/ops/upsample_nearest3d_native.h
#   inflating: /content/venv/Lib/site-packages/torch/include/ATen/ops/upsample_nearest3d_ops.h
#   inflating: /content/venv/Lib/site-packages/torch/include/ATen/ops/upsample_trilinear3d.h
#   inflating: /content/venv/Lib/site-packages/torch/include/ATen/ops/upsample_trilinear3d_backward.h
#   inflating: /content/venv/Lib/site-packages/torch/include/ATen/ops/upsample_trilinear3d_backward_compositeexplicitautogradnonfunctional_dispatch.h
#   inflating: /content/venv/Lib/site-packages/torch/include/ATen/ops/upsample_trilinear3d_backward_cpu_dispatch.h
# ...

# %%
# !source /content/venv/Scripts/activate
import sys
sys.path.append("/content/venv/Lib/site-packages")
sys.path.append("/content/venv/Lib/site-packages/ultralytics")

# %%
import ultralytics
from ultralytics import YOLO
import cv2
import torch.nn as nn
import torch
from PIL import Image

# %%
yaml_path = '/content/YOLO_data/YOLO_archive/YOLO.yaml'
file = "/content/drive/MyDrive/yolov8.yaml"

yolo_model = YOLO(file)  # build a new model from scratch
# add_custom_head(model.model)
yolo_model.train(
    data=yaml_path,
    epochs=100,
    batch=8,
    optimizer='Adam',
    name='yolov8n_custom')
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.2.4 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
